# %%
# dataset.py
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset


class ISICDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        self.df = pd.read_csv(csv_file)
        self.image_dir = image_dir
        self.transform = transform

        # ISIC 2019 class columns
        self.class_names = ["MEL", "NV", "BCC", "AK", "BKL", "DF", "VASC"]

        # Convert one-hot → class index
        self.df["label"] = self.df[self.class_names].values.argmax(axis=1)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_id = self.df.iloc[idx]["image"]
        label = int(self.df.iloc[idx]["label"])

        img_path = os.path.join(self.image_dir, f"{img_id}.jpg")
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# model.py
import torch.nn as nn
from torchvision import models


class DenseNetClassifier(nn.Module):
    def __init__(
        self,
        num_classes=7,
        freeze_backbone=True,
        dropout=0.5,
    ):
        super().__init__()

        self.model = models.densenet121(weights="IMAGENET1K_V1")

        if freeze_backbone:
            for param in self.model.features.parameters():
                param.requires_grad = False

        in_features = self.model.classifier.in_features

        # Custom classifier head
        self.model.classifier = nn.Sequential(
            nn.BatchNorm1d(in_features),
            nn.Linear(in_features, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(512, num_classes),
        )

    def forward(self, x):
        return self.model(x)

# %%
model = DenseNetClassifier(num_classes=7).to("cpu")

print(model)
# Out:
# DenseNetClassifier(
#   (model): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Sequential(
#       (0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=1024, out_features=512, bias=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Linear(in_features=512, out_features=7, bias=True)
#     )
#   )
# )

# %%
# trainer.py
import torch
from tqdm import tqdm


class Trainer:
    def __init__(self, model, device, optimizer, criterion):
        self.model = model
        self.device = device
        self.optimizer = optimizer
        self.criterion = criterion

    def train_one_epoch(self, loader):
        self.model.train()
        total_loss, correct, total = 0, 0, 0

        for images, labels in tqdm(loader, desc="Training"):
            images, labels = images.to(self.device), labels.to(self.device)

            self.optimizer.zero_grad()
            outputs = self.model(images)
            loss = self.criterion(outputs, labels)

            loss.backward()
            self.optimizer.step()

            total_loss += loss.item()
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)

        return total_loss / len(loader), correct / total

    def validate(self, loader):
        self.model.eval()
        total_loss, correct, total = 0, 0, 0

        with torch.no_grad():
            for images, labels in tqdm(loader, desc="Validation"):
                images, labels = images.to(self.device), labels.to(self.device)

                outputs = self.model(images)
                loss = self.criterion(outputs, labels)

                total_loss += loss.item()
                correct += (outputs.argmax(1) == labels).sum().item()
                total += labels.size(0)

        return total_loss / len(loader), correct / total

# %%
# train.py
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torch import nn, optim


def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    transform = transforms.Compose(
        [
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(20),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ]
    )

    train_dataset = ISICDataset(
        csv_file="../data/slice/ISIC_SUBSET/train.csv",
        image_dir="../data/slice/ISIC_SUBSET/images",
        transform=transform,
    )

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

    model = DenseNetClassifier(num_classes=7).to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.AdamW(
        [
            {"params": model.model.features.parameters(), "lr": 1e-4},
            {"params": model.model.classifier.parameters(), "lr": 1e-3},
        ]
    )
    trainer = Trainer(model, device, optimizer, criterion)

    epochs = 5
    best_loss = float("inf")
    for epoch in range(epochs):
        train_loss, train_acc = trainer.train_one_epoch(train_loader)

        print(
            f"Epoch [{epoch+1}/{epochs}] "
            f"Train Loss: {train_loss:.4f} "
            f"Train Acc: {train_acc:.4f}"
        )

        if train_loss < best_loss:
            best_loss = train_loss
            torch.save(
                {
                    "model_name": "densenet121",
                    "num_classes": 7,
                    "freeze_backbone": True,
                    "state_dict": model.state_dict(),
                },
                # f"densenet_isic_{epoch:02d}_{train_acc:.4f}.pth",
                "densenet_isic.pth",
            )


main()
# Out:
# Training: 100%|██████████| 32/32 [02:50<00:00,  5.34s/it]
# Epoch [1/5] Train Loss: 1.1603 Train Acc: 0.5775
# Training: 100%|██████████| 32/32 [02:39<00:00,  4.99s/it]
# Epoch [2/5] Train Loss: 0.8954 Train Acc: 0.6625
# Training: 100%|██████████| 32/32 [05:31<00:00, 10.37s/it]
# Epoch [3/5] Train Loss: 0.8347 Train Acc: 0.6970
# Training: 100%|██████████| 32/32 [08:53<00:00, 16.68s/it]
# Epoch [4/5] Train Loss: 0.7985 Train Acc: 0.7000
# Training: 100%|██████████| 32/32 [08:55<00:00, 16.74s/it]
# Epoch [5/5] Train Loss: 0.7532 Train Acc: 0.7270

# %% [markdown]
# # Validation

# %%
# validate_isic_onehot.py
import pandas as pd
import torch
from torchvision import transforms
from PIL import Image
from pathlib import Path

# =====================
# CONFIG
# =====================
MODEL_PATH = "densenet_isic.pth"
IMAGE_DIR = "../data/slice/ISIC_SUBSET/images"
VAL_CSV = "../data/slice/ISIC_SUBSET/val.csv"
IMG_SIZE = 224

# Only include the classes used for training
CLASS_NAMES = ["MEL", "NV", "BCC", "AK", "BKL", "DF", "VASC"]

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# =====================
# IMAGE TRANSFORM
# =====================
transform = transforms.Compose(
    [
        transforms.Resize((IMG_SIZE, IMG_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]
)


# =====================
# LOAD MODEL
# =====================
def load_model(path):
    checkpoint = torch.load(path, map_location=DEVICE)
    model = DenseNetClassifier(num_classes=len(CLASS_NAMES), freeze_backbone=False).to(
        DEVICE
    )
    model.load_state_dict(checkpoint["state_dict"])
    model.eval()
    return model


# =====================
# PREDICT SINGLE IMAGE
# =====================
def predict(model, img_path):
    img = Image.open(img_path).convert("RGB")
    img = transform(img).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        outputs = model(img)
        pred_idx = outputs.argmax(1).item()
        confidence = torch.softmax(outputs, dim=1)[0, pred_idx].item()
    return pred_idx, CLASS_NAMES[pred_idx], confidence


# =====================
# MAIN VALIDATION
# =====================
def main():
    model = load_model(MODEL_PATH)
    df = pd.read_csv(VAL_CSV)

    total = 0
    correct = 0
    results = []

    for _, row in df.iterrows():
        img_name = row["image"].strip() + ".jpg"
        img_path = Path(IMAGE_DIR) / img_name
        if not img_path.exists():
            print(f"WARNING: {img_path} not found, skipping.")
            continue

        pred_idx, pred_class, conf = predict(model, img_path)

        # --- ground truth from one-hot columns ---
        gt_idx = row[1 : 1 + len(CLASS_NAMES)].values.argmax()
        gt_class = CLASS_NAMES[gt_idx]

        total += 1
        correct += int(pred_idx == gt_idx)

        results.append(
            {
                "image": img_name,
                "gt_label": gt_class,
                "prediction": pred_class,
                "confidence": round(conf, 3),
            }
        )

        print(f"{img_name}: GT={gt_class} | PRED={pred_class} ({conf:.2f})")

    # --- final accuracy ---
    val_acc = correct / total if total > 0 else 0
    print(f"\nValidation Accuracy: {val_acc:.4f}")

    # --- save predictions ---
    pd.DataFrame(results).to_csv("predictions_val.csv", index=False)
    print("Predictions saved to predictions_val.csv")


if __name__ == "__main__":
    main()
# Out:
# ISIC_0054697.jpg: GT=BCC | PRED=BKL (0.37)
# ISIC_0000360.jpg: GT=NV | PRED=NV (0.74)
# ISIC_0059394.jpg: GT=BCC | PRED=BCC (0.78)
# ISIC_0026375.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0059292.jpg: GT=NV | PRED=NV (0.63)
# ISIC_0031400.jpg: GT=BCC | PRED=BCC (1.00)
# ISIC_0028987.jpg: GT=NV | PRED=NV (0.81)
# ISIC_0055169.jpg: GT=MEL | PRED=MEL (0.97)
# ISIC_0068495.jpg: GT=MEL | PRED=MEL (0.80)
# ISIC_0031602.jpg: GT=NV | PRED=NV (0.74)
# ISIC_0066810.jpg: GT=BKL | PRED=BKL (0.42)
# ISIC_0063352.jpg: GT=BCC | PRED=BCC (0.65)
# ISIC_0025657.jpg: GT=NV | PRED=NV (0.82)
# ISIC_0064072.jpg: GT=MEL | PRED=MEL (0.79)
# ISIC_0073021.jpg: GT=BKL | PRED=BCC (0.58)
# ISIC_0060204.jpg: GT=BKL | PRED=BCC (0.34)
# ISIC_0032034.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0072668.jpg: GT=NV | PRED=NV (0.90)
# ISIC_0066796.jpg: GT=NV | PRED=NV (0.74)
# ISIC_0031807.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0069383.jpg: GT=NV | PRED=NV (0.65)
# ISIC_0064521.jpg: GT=MEL | PRED=MEL (0.82)
# ISIC_0053685.jpg: GT=MEL | PRED=BCC (0.35)
# ISIC_0060406.jpg: GT=MEL | PRED=MEL (0.81)
# ISIC_0063516.jpg: GT=NV | PRED=MEL (0.59)
# ISIC_0025605.jpg: GT=AK | PRED=NV (0.59)
# ISIC_0069492.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0029261.jpg: GT=NV | PRED=BCC (0.55)
# ISIC_0029522.jpg: GT=BKL | PRED=NV (0.93)
# ISIC_0026531.jpg: GT=MEL | PRED=MEL (0.73)
# ISIC_0072828.jpg: GT=MEL | PRED=MEL (0.46)
# ISIC_0032638.jpg: GT=MEL | PRED=NV (0.64)
# ISIC_0060162.jpg: GT=BCC | PRED=MEL (0.62)
# ISIC_0029862.jpg: GT=NV | PRED=NV (0.80)
# ISIC_0034229.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0059921.jpg: GT=NV | PRED=NV (0.61)
# ISIC_0034184.jpg: GT=NV | PRED=NV (0.56)
# ISIC_0012495_downsampled.jpg: GT=NV | PRED=NV (0.58)
# ISIC_0029508.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0031872.jpg: GT=BKL | PRED=BCC (0.39)
# ISIC_0013782_downsampled.jpg: GT=BKL | PRED=NV (0.56)
# ISIC_0029275.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0024377.jpg: GT=NV | PRED=NV (0.80)
# ISIC_0034120.jpg: GT=MEL | PRED=NV (0.59)
# ISIC_0054693.jpg: GT=BKL | PRED=MEL (0.51)
# ISIC_0032036.jpg: GT=MEL | PRED=NV (0.67)
# ISIC_0060289.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0065578.jpg: GT=NV | PRED=BKL (0.49)
# ISIC_0032612.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0056707.jpg: GT=NV | PRED=NV (0.81)
# ISIC_0030933.jpg: GT=NV | PRED=NV (0.35)
# ISIC_0029052.jpg: GT=DF | PRED=NV (0.54)
# ISIC_0026520.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0033738.jpg: GT=NV | PRED=BKL (0.37)
# ISIC_0016068_downsampled.jpg: GT=NV | PRED=MEL (0.47)
# ISIC_0066109.jpg: GT=MEL | PRED=NV (0.97)
# ISIC_0073148.jpg: GT=BCC | PRED=BKL (0.37)
# ISIC_0032724.jpg: GT=MEL | PRED=MEL (0.91)
# ISIC_0026762.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0069929.jpg: GT=MEL | PRED=MEL (0.96)
# ISIC_0026246.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0057344.jpg: GT=MEL | PRED=NV (0.96)
# ISIC_0000471.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0054023.jpg: GT=NV | PRED=NV (0.72)
# ISIC_0024799.jpg: GT=BCC | PRED=BCC (0.93)
# ISIC_0032856.jpg: GT=MEL | PRED=MEL (0.84)
# ISIC_0066756.jpg: GT=MEL | PRED=MEL (0.37)
# ISIC_0065142.jpg: GT=MEL | PRED=BKL (0.42)
# ISIC_0057701.jpg: GT=NV | PRED=NV (0.57)
# ISIC_0064187.jpg: GT=NV | PRED=MEL (0.68)
# ISIC_0029797.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0068975.jpg: GT=MEL | PRED=NV (0.76)
# ISIC_0028065.jpg: GT=MEL | PRED=NV (0.99)
# ISIC_0024319.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0061900.jpg: GT=MEL | PRED=MEL (0.86)
# ISIC_0032239.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0059729.jpg: GT=BCC | PRED=MEL (0.71)
# ISIC_0070991.jpg: GT=MEL | PRED=MEL (0.99)
# ISIC_0063181.jpg: GT=MEL | PRED=NV (0.95)
# ISIC_0067809.jpg: GT=NV | PRED=MEL (0.52)
# ISIC_0029012.jpg: GT=BKL | PRED=NV (0.49)
# ISIC_0014579_downsampled.jpg: GT=BKL | PRED=NV (0.81)
# ISIC_0066360.jpg: GT=AK | PRED=AK (0.44)
# ISIC_0027818.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0025696.jpg: GT=MEL | PRED=BKL (0.43)
# ISIC_0060632.jpg: GT=NV | PRED=MEL (0.66)
# ISIC_0072716.jpg: GT=AK | PRED=MEL (0.61)
# ISIC_0067420.jpg: GT=NV | PRED=MEL (0.82)
# ISIC_0026042.jpg: GT=BKL | PRED=MEL (0.54)
# ISIC_0033778.jpg: GT=BKL | PRED=MEL (0.63)
# ISIC_0065075.jpg: GT=BCC | PRED=BCC (0.97)
# ISIC_0061891.jpg: GT=BCC | PRED=BCC (0.42)
# ISIC_0024467.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0055890.jpg: GT=BCC | PRED=BCC (0.73)
# ISIC_0025622.jpg: GT=DF | PRED=NV (0.43)
# ISIC_0064750.jpg: GT=BKL | PRED=BCC (0.90)
# ISIC_0056205.jpg: GT=BCC | PRED=BCC (0.58)
# ISIC_0027690.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0029287.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0028555.jpg: GT=BKL | PRED=MEL (0.53)
# ISIC_0069365.jpg: GT=MEL | PRED=NV (0.56)
# ISIC_0068480.jpg: GT=BCC | PRED=BCC (0.69)
# ISIC_0058515.jpg: GT=MEL | PRED=BCC (0.74)
# ISIC_0071432.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0026751.jpg: GT=NV | PRED=NV (0.50)
# ISIC_0067040.jpg: GT=NV | PRED=NV (0.42)
# ISIC_0030322.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0070536.jpg: GT=BCC | PRED=BCC (0.43)
# ISIC_0032630.jpg: GT=MEL | PRED=MEL (0.91)
# ISIC_0057586.jpg: GT=AK | PRED=BCC (0.76)
# ISIC_0012493_downsampled.jpg: GT=NV | PRED=NV (0.60)
# ISIC_0060475.jpg: GT=NV | PRED=NV (0.66)
# ISIC_0011132.jpg: GT=MEL | PRED=MEL (0.57)
# ISIC_0059402.jpg: GT=BCC | PRED=BCC (0.93)
# ISIC_0033774.jpg: GT=NV | PRED=MEL (0.63)
# ISIC_0025573.jpg: GT=MEL | PRED=NV (0.65)
# ISIC_0012318_downsampled.jpg: GT=NV | PRED=NV (0.66)
# ISIC_0025513.jpg: GT=BCC | PRED=BCC (0.44)
# ISIC_0012291_downsampled.jpg: GT=BKL | PRED=MEL (0.31)
# ISIC_0029150.jpg: GT=NV | PRED=NV (0.76)
# ISIC_0024928.jpg: GT=NV | PRED=NV (0.90)
# ISIC_0011105.jpg: GT=NV | PRED=NV (0.80)
# ISIC_0028120.jpg: GT=BKL | PRED=NV (0.64)
# ISIC_0055334.jpg: GT=BCC | PRED=BCC (0.71)
# ISIC_0059643.jpg: GT=NV | PRED=NV (0.49)
# ISIC_0064883.jpg: GT=BKL | PRED=NV (0.52)
# ISIC_0029767.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0029682.jpg: GT=BKL | PRED=MEL (0.67)
# ISIC_0030321.jpg: GT=DF | PRED=BCC (0.72)
# ISIC_0058152.jpg: GT=MEL | PRED=BCC (0.65)
# ISIC_0030602.jpg: GT=MEL | PRED=NV (0.52)
# ISIC_0065182.jpg: GT=NV | PRED=BCC (0.51)
# ISIC_0014545_downsampled.jpg: GT=MEL | PRED=NV (0.91)
# ISIC_0057914.jpg: GT=MEL | PRED=AK (0.45)
# ISIC_0031416.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0025568.jpg: GT=NV | PRED=NV (0.56)
# ISIC_0068895.jpg: GT=MEL | PRED=MEL (0.75)
# ISIC_0028588.jpg: GT=NV | PRED=BCC (0.60)
# ISIC_0029696.jpg: GT=NV | PRED=MEL (0.49)
# ISIC_0028316.jpg: GT=BCC | PRED=BCC (0.37)
# ISIC_0029943.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0067623.jpg: GT=BKL | PRED=AK (0.50)
# ISIC_0031792.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0059210.jpg: GT=BCC | PRED=BCC (0.68)
# ISIC_0014780_downsampled.jpg: GT=NV | PRED=NV (0.64)
# ISIC_0000213.jpg: GT=NV | PRED=NV (0.60)
# ISIC_0026886.jpg: GT=NV | PRED=NV (0.75)
# ISIC_0069259.jpg: GT=BCC | PRED=BCC (0.64)
# ISIC_0065756.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0061858.jpg: GT=NV | PRED=NV (0.89)
# ISIC_0066716.jpg: GT=MEL | PRED=MEL (0.88)
# ISIC_0027837.jpg: GT=NV | PRED=NV (0.30)
# ISIC_0060680.jpg: GT=BCC | PRED=BCC (0.63)
# ISIC_0032424.jpg: GT=MEL | PRED=MEL (0.57)
# ISIC_0060673.jpg: GT=BCC | PRED=BCC (0.48)
# ISIC_0015363_downsampled.jpg: GT=NV | PRED=BCC (0.51)
# ISIC_0068932.jpg: GT=MEL | PRED=MEL (0.71)
# ISIC_0056673.jpg: GT=NV | PRED=MEL (0.77)
# ISIC_0065508.jpg: GT=BCC | PRED=MEL (0.78)
# ISIC_0024755.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0055474.jpg: GT=MEL | PRED=MEL (0.81)
# ISIC_0064735.jpg: GT=AK | PRED=BKL (0.50)
# ISIC_0053733.jpg: GT=BCC | PRED=BCC (0.91)
# ISIC_0060962.jpg: GT=MEL | PRED=BKL (0.73)
# ISIC_0032728.jpg: GT=NV | PRED=NV (0.64)
# ISIC_0028117.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0025655.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0070521.jpg: GT=MEL | PRED=MEL (0.67)
# ISIC_0067260.jpg: GT=MEL | PRED=MEL (0.40)
# ISIC_0025447.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0056578.jpg: GT=NV | PRED=NV (0.50)
# ISIC_0024417.jpg: GT=NV | PRED=NV (0.89)
# ISIC_0057872.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0058966.jpg: GT=BCC | PRED=BCC (0.82)
# ISIC_0034002.jpg: GT=MEL | PRED=MEL (0.54)
# ISIC_0033084.jpg: GT=MEL | PRED=NV (0.47)
# ISIC_0061859.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0014897_downsampled.jpg: GT=MEL | PRED=NV (0.83)
# ISIC_0071884.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0010365.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0033590.jpg: GT=NV | PRED=NV (0.86)
# ISIC_0030346.jpg: GT=BKL | PRED=BKL (0.48)
# ISIC_0067386.jpg: GT=BCC | PRED=BCC (0.87)
# ISIC_0031173.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0070017.jpg: GT=MEL | PRED=MEL (0.88)
# ISIC_0032961.jpg: GT=NV | PRED=NV (0.60)
# ISIC_0032619.jpg: GT=NV | PRED=NV (0.35)
# ISIC_0026501.jpg: GT=NV | PRED=NV (0.57)
# ISIC_0012725_downsampled.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0000179_downsampled.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0069992.jpg: GT=NV | PRED=NV (0.47)
# ISIC_0053478.jpg: GT=AK | PRED=NV (0.72)
# ISIC_0057798.jpg: GT=BKL | PRED=BCC (0.83)
# ISIC_0033987.jpg: GT=BKL | PRED=BKL (0.38)
# ISIC_0061072.jpg: GT=NV | PRED=NV (0.57)
# ISIC_0034214.jpg: GT=VASC | PRED=BCC (0.58)
# ISIC_0064980.jpg: GT=MEL | PRED=MEL (0.98)
# ISIC_0059115.jpg: GT=BCC | PRED=BCC (0.99)
# ISIC_0062117.jpg: GT=MEL | PRED=BCC (0.43)
# ISIC_0026903.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0058110.jpg: GT=NV | PRED=NV (0.82)
# ISIC_0067438.jpg: GT=MEL | PRED=MEL (0.82)
# ISIC_0061987.jpg: GT=NV | PRED=MEL (0.74)
# ISIC_0059149.jpg: GT=BCC | PRED=BCC (0.51)
# ISIC_0062447.jpg: GT=MEL | PRED=BKL (0.44)
# ISIC_0057605.jpg: GT=NV | PRED=MEL (0.67)
# ISIC_0058761.jpg: GT=NV | PRED=BCC (0.91)
# ISIC_0025243.jpg: GT=NV | PRED=NV (0.71)
# ISIC_0028957.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0029630.jpg: GT=MEL | PRED=BCC (0.46)
# ISIC_0030612.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0014197_downsampled.jpg: GT=NV | PRED=NV (0.67)
# ISIC_0027219.jpg: GT=BKL | PRED=NV (0.49)
# ISIC_0062501.jpg: GT=BCC | PRED=NV (0.49)
# ISIC_0030632.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0029367.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0071960.jpg: GT=BCC | PRED=BCC (0.89)
# ISIC_0058712.jpg: GT=NV | PRED=NV (0.60)
# ISIC_0028979.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0010190.jpg: GT=NV | PRED=MEL (0.58)
# ISIC_0056870.jpg: GT=BCC | PRED=BCC (0.96)
# ISIC_0025304.jpg: GT=NV | PRED=NV (0.75)
# ISIC_0053937.jpg: GT=NV | PRED=MEL (0.62)
# ISIC_0065898.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0024983.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0029591.jpg: GT=MEL | PRED=MEL (0.68)
# ISIC_0029085.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0010372.jpg: GT=MEL | PRED=MEL (0.61)
# ISIC_0070966.jpg: GT=BCC | PRED=BCC (0.45)
# ISIC_0055851.jpg: GT=NV | PRED=MEL (0.55)
# ISIC_0056403.jpg: GT=MEL | PRED=MEL (0.80)
# ISIC_0034128.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0027627.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0070279.jpg: GT=NV | PRED=BKL (0.51)
# ISIC_0014653_downsampled.jpg: GT=BKL | PRED=BKL (0.45)
# ISIC_0028954.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0026303.jpg: GT=NV | PRED=NV (0.61)
# ISIC_0027246.jpg: GT=NV | PRED=NV (0.65)
# ISIC_0068993.jpg: GT=MEL | PRED=MEL (0.50)
# ISIC_0057482.jpg: GT=MEL | PRED=NV (0.95)
# ISIC_0029185.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0061806.jpg: GT=MEL | PRED=MEL (0.99)
# ISIC_0031448.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0029564.jpg: GT=BCC | PRED=NV (0.49)
# ISIC_0014249_downsampled.jpg: GT=MEL | PRED=MEL (0.58)
# ISIC_0069236.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0000148_downsampled.jpg: GT=MEL | PRED=NV (0.97)
# ISIC_0070662.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0064286.jpg: GT=BCC | PRED=MEL (0.45)
# ISIC_0024765.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0032690.jpg: GT=MEL | PRED=NV (0.44)
# ISIC_0061235.jpg: GT=BKL | PRED=BKL (0.43)
# ISIC_0025279.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0027803.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0069160.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0064341.jpg: GT=MEL | PRED=MEL (0.93)
# ISIC_0033335.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0009923.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0028671.jpg: GT=BCC | PRED=MEL (0.71)
# ISIC_0061395.jpg: GT=NV | PRED=NV (0.72)
# ISIC_0063182.jpg: GT=MEL | PRED=BCC (0.55)
# ISIC_0032286.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0062803.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0031559.jpg: GT=NV | PRED=NV (0.97)
# ISIC_0072549.jpg: GT=BCC | PRED=NV (0.69)
# ISIC_0056113.jpg: GT=MEL | PRED=NV (0.81)
# ISIC_0063704.jpg: GT=MEL | PRED=MEL (0.43)
# ISIC_0032073.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0061421.jpg: GT=NV | PRED=MEL (0.63)
# ISIC_0063318.jpg: GT=MEL | PRED=NV (0.65)
# ISIC_0026441.jpg: GT=BKL | PRED=NV (0.98)
# ISIC_0071906.jpg: GT=MEL | PRED=NV (0.69)
# ISIC_0064384.jpg: GT=NV | PRED=NV (0.32)
# ISIC_0014702_downsampled.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0034011.jpg: GT=BKL | PRED=MEL (0.46)
# ISIC_0026964.jpg: GT=NV | PRED=NV (0.87)
# ISIC_0031304.jpg: GT=NV | PRED=MEL (0.66)
# ISIC_0033328.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0027174.jpg: GT=MEL | PRED=BCC (0.46)
# ISIC_0028305.jpg: GT=NV | PRED=NV (0.86)
# ISIC_0068585.jpg: GT=BCC | PRED=MEL (0.38)
# ISIC_0030259.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0015220_downsampled.jpg: GT=BKL | PRED=NV (0.79)
# ISIC_0027865.jpg: GT=BCC | PRED=BCC (0.93)
# ISIC_0010204.jpg: GT=NV | PRED=NV (0.62)
# ISIC_0063061.jpg: GT=MEL | PRED=MEL (0.96)
# ISIC_0032293.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0010063.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0026590.jpg: GT=BKL | PRED=MEL (0.56)
# ISIC_0024910.jpg: GT=BKL | PRED=NV (0.45)
# ISIC_0028831.jpg: GT=NV | PRED=NV (0.82)
# ISIC_0066940.jpg: GT=BCC | PRED=BCC (0.97)
# ISIC_0068021.jpg: GT=BCC | PRED=BCC (0.80)
# ISIC_0062981.jpg: GT=NV | PRED=NV (0.74)
# ISIC_0027921.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0064579.jpg: GT=MEL | PRED=MEL (0.45)
# ISIC_0024514.jpg: GT=NV | PRED=NV (0.70)
# ISIC_0053671.jpg: GT=MEL | PRED=BCC (0.76)
# ISIC_0068030.jpg: GT=BCC | PRED=MEL (0.69)
# ISIC_0024796.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0066504.jpg: GT=VASC | PRED=BCC (0.51)
# ISIC_0066282.jpg: GT=BCC | PRED=BCC (0.52)
# ISIC_0014933_downsampled.jpg: GT=NV | PRED=NV (0.90)
# ISIC_0027076.jpg: GT=MEL | PRED=MEL (0.56)
# ISIC_0067693.jpg: GT=NV | PRED=NV (0.47)
# ISIC_0062965.jpg: GT=BCC | PRED=NV (0.72)
# ISIC_0025982.jpg: GT=BKL | PRED=MEL (0.55)
# ISIC_0068107.jpg: GT=MEL | PRED=MEL (0.71)
# ISIC_0061710.jpg: GT=MEL | PRED=NV (0.56)
# ISIC_0061690.jpg: GT=MEL | PRED=BCC (0.79)
# ISIC_0054914.jpg: GT=MEL | PRED=MEL (0.86)
# ISIC_0029273.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0067408.jpg: GT=BKL | PRED=BCC (0.32)
# ISIC_0064831.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0033172.jpg: GT=NV | PRED=MEL (0.60)
# ISIC_0032827.jpg: GT=BKL | PRED=NV (0.66)
# ISIC_0059912.jpg: GT=BCC | PRED=BCC (0.30)
# ISIC_0069063.jpg: GT=MEL | PRED=MEL (0.99)
# ISIC_0072687.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0027152.jpg: GT=NV | PRED=NV (0.50)
# ISIC_0027825.jpg: GT=BCC | PRED=BCC (0.92)
# ISIC_0033690.jpg: GT=NV | PRED=NV (0.59)
# ISIC_0071060.jpg: GT=MEL | PRED=NV (0.70)
# ISIC_0014537_downsampled.jpg: GT=BKL | PRED=BKL (0.74)
# ISIC_0064496.jpg: GT=BCC | PRED=BCC (0.48)
# ISIC_0058232.jpg: GT=BCC | PRED=BCC (0.93)
# ISIC_0063693.jpg: GT=MEL | PRED=BCC (0.58)
# ISIC_0027401.jpg: GT=NV | PRED=NV (0.76)
# ISIC_0029734.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0059782.jpg: GT=NV | PRED=MEL (0.79)
# ISIC_0067323.jpg: GT=NV | PRED=MEL (0.81)
# ISIC_0025387.jpg: GT=BKL | PRED=BKL (0.35)
# ISIC_0031902.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0066895.jpg: GT=AK | PRED=BCC (0.77)
# ISIC_0063313.jpg: GT=NV | PRED=MEL (0.51)
# ISIC_0030011.jpg: GT=DF | PRED=NV (0.26)
# ISIC_0070625.jpg: GT=BCC | PRED=BCC (0.84)
# ISIC_0063090.jpg: GT=BCC | PRED=NV (0.42)
# ISIC_0070462.jpg: GT=AK | PRED=AK (0.54)
# ISIC_0012207_downsampled.jpg: GT=BKL | PRED=NV (0.66)
# ISIC_0031846.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0031096.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0060687.jpg: GT=BCC | PRED=BCC (0.74)
# ISIC_0033187.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0033868.jpg: GT=BKL | PRED=NV (0.87)
# ISIC_0060170.jpg: GT=NV | PRED=NV (0.87)
# ISIC_0067412.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0072271.jpg: GT=MEL | PRED=NV (0.81)
# ISIC_0025263.jpg: GT=NV | PRED=NV (0.94)
# ISIC_0032057.jpg: GT=VASC | PRED=NV (0.55)
# ISIC_0070850.jpg: GT=NV | PRED=NV (0.83)
# ISIC_0072568.jpg: GT=MEL | PRED=MEL (0.96)
# ISIC_0053894.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0062024.jpg: GT=AK | PRED=AK (0.76)
# ISIC_0054506.jpg: GT=MEL | PRED=NV (0.80)
# ISIC_0073097.jpg: GT=MEL | PRED=MEL (0.91)
# ISIC_0069135.jpg: GT=BKL | PRED=MEL (0.37)
# ISIC_0073229.jpg: GT=BCC | PRED=BCC (0.49)
# ISIC_0013109_downsampled.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0033624.jpg: GT=MEL | PRED=BCC (0.86)
# ISIC_0056995.jpg: GT=BCC | PRED=BCC (0.86)
# ISIC_0065852.jpg: GT=NV | PRED=NV (0.81)
# ISIC_0032696.jpg: GT=BCC | PRED=BCC (0.94)
# ISIC_0064264.jpg: GT=BKL | PRED=BCC (0.54)
# ISIC_0014779_downsampled.jpg: GT=NV | PRED=NV (0.54)
# ISIC_0072764.jpg: GT=NV | PRED=BKL (0.47)
# ISIC_0065748.jpg: GT=MEL | PRED=BKL (0.70)
# ISIC_0072709.jpg: GT=BCC | PRED=BCC (0.53)
# ISIC_0032841.jpg: GT=MEL | PRED=MEL (0.57)
# ISIC_0060496.jpg: GT=NV | PRED=BCC (0.55)
# ISIC_0056452.jpg: GT=NV | PRED=NV (0.68)
# ISIC_0069746.jpg: GT=MEL | PRED=BCC (0.91)
# ISIC_0026088.jpg: GT=NV | PRED=NV (0.45)
# ISIC_0061713.jpg: GT=MEL | PRED=MEL (0.94)
# ISIC_0059418.jpg: GT=NV | PRED=NV (0.52)
# ISIC_0066163.jpg: GT=NV | PRED=NV (0.91)
# ISIC_0033633.jpg: GT=NV | PRED=NV (0.49)
# ISIC_0058965.jpg: GT=NV | PRED=NV (0.33)
# ISIC_0066584.jpg: GT=NV | PRED=BCC (0.63)
# ISIC_0059811.jpg: GT=BCC | PRED=BCC (0.76)
# ISIC_0024503.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0028336.jpg: GT=BKL | PRED=NV (0.95)
# ISIC_0031606.jpg: GT=NV | PRED=MEL (0.48)
# ISIC_0063958.jpg: GT=MEL | PRED=MEL (0.61)
# ISIC_0033469.jpg: GT=MEL | PRED=MEL (0.87)
# ISIC_0027427.jpg: GT=NV | PRED=NV (0.49)
# ISIC_0071861.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0012735_downsampled.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0063510.jpg: GT=BKL | PRED=BKL (0.45)
# ISIC_0067552.jpg: GT=BCC | PRED=NV (0.34)
# ISIC_0057193.jpg: GT=NV | PRED=MEL (0.53)
# ISIC_0015007_downsampled.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0032371.jpg: GT=MEL | PRED=BCC (0.33)
# ISIC_0060403.jpg: GT=MEL | PRED=BCC (0.94)
# ISIC_0016054_downsampled.jpg: GT=NV | PRED=BKL (0.45)
# ISIC_0032579.jpg: GT=NV | PRED=NV (0.82)
# ISIC_0070507.jpg: GT=AK | PRED=BKL (0.66)
# ISIC_0014814_downsampled.jpg: GT=NV | PRED=NV (0.85)
# ISIC_0071356.jpg: GT=BKL | PRED=NV (0.84)
# ISIC_0059933.jpg: GT=NV | PRED=BCC (0.36)
# ISIC_0014638_downsampled.jpg: GT=BKL | PRED=BKL (0.51)
# ISIC_0061574.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0027166.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0027893.jpg: GT=BKL | PRED=NV (0.67)
# ISIC_0065826.jpg: GT=BCC | PRED=AK (0.53)
# ISIC_0034213.jpg: GT=NV | PRED=NV (0.55)
# ISIC_0031543.jpg: GT=MEL | PRED=MEL (0.59)
# ISIC_0030783.jpg: GT=BKL | PRED=NV (0.48)
# ISIC_0026563.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0000351.jpg: GT=NV | PRED=NV (0.93)
# ISIC_0024719.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0068617.jpg: GT=MEL | PRED=MEL (0.79)
# ISIC_0031379.jpg: GT=NV | PRED=MEL (0.67)
# ISIC_0028115.jpg: GT=NV | PRED=NV (0.90)
# ISIC_0070723.jpg: GT=VASC | PRED=BCC (0.41)
# ISIC_0025972.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0072365.jpg: GT=BCC | PRED=BCC (0.51)
# ISIC_0032534.jpg: GT=BKL | PRED=BCC (0.84)
# ISIC_0061303.jpg: GT=BCC | PRED=BCC (0.80)
# ISIC_0027808.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0055249.jpg: GT=MEL | PRED=MEL (0.42)
# ISIC_0058145.jpg: GT=NV | PRED=MEL (0.73)
# ISIC_0054362.jpg: GT=BCC | PRED=NV (0.58)
# ISIC_0028081.jpg: GT=NV | PRED=NV (0.89)
# ISIC_0057875.jpg: GT=NV | PRED=NV (0.83)
# ISIC_0062954.jpg: GT=MEL | PRED=MEL (0.60)
# ISIC_0000467.jpg: GT=NV | PRED=NV (0.96)
# ISIC_0064741.jpg: GT=BKL | PRED=MEL (0.46)
# ISIC_0053810.jpg: GT=MEL | PRED=MEL (0.40)
# ISIC_0029986.jpg: GT=NV | PRED=MEL (0.57)
# ISIC_0000271.jpg: GT=NV | PRED=NV (0.86)
# ISIC_0001181_downsampled.jpg: GT=NV | PRED=NV (0.64)
# ISIC_0029209.jpg: GT=MEL | PRED=MEL (0.44)
# ISIC_0065584.jpg: GT=AK | PRED=BCC (0.95)
# ISIC_0059648.jpg: GT=NV | PRED=BKL (0.53)
# ISIC_0061496.jpg: GT=MEL | PRED=BKL (0.32)
# ISIC_0064052.jpg: GT=NV | PRED=MEL (0.58)
# ISIC_0027326.jpg: GT=BKL | PRED=NV (0.71)
# ISIC_0024944.jpg: GT=NV | PRED=NV (0.98)
# ISIC_0053718.jpg: GT=NV | PRED=NV (0.68)
# ISIC_0029819.jpg: GT=MEL | PRED=NV (0.73)
# ISIC_0054819.jpg: GT=MEL | PRED=NV (0.56)
# ISIC_0030903.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0025367.jpg: GT=NV | PRED=NV (0.90)
# ISIC_0031422.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0024350.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0024786.jpg: GT=BKL | PRED=MEL (0.49)
# ISIC_0032256.jpg: GT=NV | PRED=NV (1.00)
# ISIC_0026102.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0029828.jpg: GT=NV | PRED=NV (0.55)
# ISIC_0067519.jpg: GT=AK | PRED=MEL (0.66)
# ISIC_0063428.jpg: GT=MEL | PRED=MEL (0.92)
# ISIC_0058812.jpg: GT=NV | PRED=BKL (0.57)
# ISIC_0000541.jpg: GT=NV | PRED=NV (0.76)
# ISIC_0053764.jpg: GT=AK | PRED=MEL (0.81)
# ISIC_0071164.jpg: GT=MEL | PRED=BCC (0.57)
# ISIC_0062601.jpg: GT=BCC | PRED=BCC (0.75)
# ISIC_0067554.jpg: GT=BCC | PRED=MEL (0.59)
# ISIC_0030231.jpg: GT=BKL | PRED=BKL (0.31)
# ISIC_0026768.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0067251.jpg: GT=BCC | PRED=BCC (0.95)
# ISIC_0070297.jpg: GT=AK | PRED=AK (0.54)
# ISIC_0062167.jpg: GT=BCC | PRED=BCC (0.95)
# ISIC_0073228.jpg: GT=BKL | PRED=NV (0.80)
# ISIC_0070565.jpg: GT=BKL | PRED=MEL (0.72)
# ISIC_0063320.jpg: GT=AK | PRED=AK (0.46)
# ISIC_0033649.jpg: GT=NV | PRED=NV (0.72)
# ISIC_0033923.jpg: GT=NV | PRED=NV (0.79)
# ISIC_0028109.jpg: GT=MEL | PRED=NV (0.76)
# ISIC_0014617_downsampled.jpg: GT=BKL | PRED=NV (0.58)
# ISIC_0029609.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0062822.jpg: GT=NV | PRED=BCC (0.88)
# ISIC_0062097.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0071878.jpg: GT=BCC | PRED=BCC (0.61)
# ISIC_0027863.jpg: GT=MEL | PRED=MEL (0.71)
# ISIC_0030462.jpg: GT=NV | PRED=NV (0.69)
# ISIC_0063400.jpg: GT=BCC | PRED=NV (0.69)
# ISIC_0069109.jpg: GT=BCC | PRED=BCC (0.35)
# ISIC_0063097.jpg: GT=BCC | PRED=BCC (0.99)
# ISIC_0000325.jpg: GT=NV | PRED=NV (0.59)
# ISIC_0026380.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0025406.jpg: GT=NV | PRED=NV (0.95)
# ISIC_0056369.jpg: GT=NV | PRED=NV (0.88)
# ISIC_0031529.jpg: GT=MEL | PRED=NV (0.98)
# ISIC_0024629.jpg: GT=NV | PRED=NV (0.89)
# ISIC_0030535.jpg: GT=NV | PRED=NV (0.84)
# ISIC_0029796.jpg: GT=NV | PRED=NV (0.99)
# ISIC_0033496.jpg: GT=MEL | PRED=NV (0.52)
# ISIC_0025546.jpg: GT=MEL | PRED=NV (0.79)
# ISIC_0013399_downsampled.jpg: GT=NV | PRED=BKL (0.42)
# ISIC_0028869.jpg: GT=NV | PRED=NV (0.92)
# ISIC_0033825.jpg: GT=NV | PRED=NV (0.59)
# ISIC_0054764.jpg: GT=BCC | PRED=BCC (0.54)
# ISIC_0014755_downsampled.jpg: GT=NV | PRED=NV (0.65)
# ISIC_0071383.jpg: GT=VASC | PRED=NV (0.60)
# ISIC_0071911.jpg: GT=NV | PRED=MEL (0.37)
# ISIC_0015969_downsampled.jpg: GT=NV | PRED=MEL (0.47)
# ISIC_0056620.jpg: GT=BKL | PRED=BCC (0.53)
# ISIC_0032890.jpg: GT=VASC | PRED=VASC (0.49)
# ISIC_0054666.jpg: GT=AK | PRED=BCC (0.63)
#
# Validation Accuracy: 0.6420
# Predictions saved to predictions_val.csv
